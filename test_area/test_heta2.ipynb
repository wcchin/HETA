# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# %%
g = nx.read_pajek('../data/net/jazz.net')
g = nx.Graph(g)

# %%
nx.draw_networkx(g)
# Out:
# /home/benny/.pyenv/versions/anaconda3-2019.07/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
m0 = nx.to_numpy_matrix(g)
plt.matshow(m0)

# %%
import heta.HETA as heta

# %%
g1, ext_dic, int_dic = heta.bridge_or_bond(g, times=3)
# Out:
# Calculating average shortest path length: 100%|██████████| 1000/1000 [00:00<00:00, 16474.68it/s]
# no_nodes: 198 , no_edges: 2742
# calculating kmax
# max layer is 1
# computing link property R
# calculating external threshold
# False
# False
# False
# completed randomizing 0 approx. used time:  0.04299360513687134 mins for about 10 iter.
# identifying: 100%|██████████| 2742/2742 [00:00<00:00, 25442.01it/s]
# randomizing used time: 0.04360942840576172 minutes
# done randomized and calculate external threshold
# done identify edge types

# %%
import importlib

# %%
import heta.HETA2 as heta2
importlib.reload(heta2)
# Out:
# <module 'heta.HETA2' from '/home/benny/Workspaces/mypackage/HETA/heta/HETA2.py'>

# %%
g2, ext_dic, int_dic = heta2.bridge_or_bond(g, times=1)
# Out:
# Calculating average shortest path length: 100%|██████████| 1000/1000 [00:00<00:00, 17492.37it/s]
# no_nodes: 198 , no_edges: 2742
# calculating kmax
# max layer is 1
# computing link property R
# calculating external threshold
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/benny/.pyenv/versions/anaconda3-2019.07/lib/python3.7/site-packages/multiprocess/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/benny/.pyenv/versions/anaconda3-2019.07/lib/python3.7/site-packages/pathos/helpers/mp_helper.py", line 15, in <lambda>
#     func = lambda args: f(*args)
#   File "/home/benny/Workspaces/mypackage/HETA/heta/HETA2.py", line 305, in randomizing
#     print(output_random)
# NameError: name 'output_random' is not defined
# """
#
# ...

# %%
for u,v,d1 in g1.edges(data=True):
    #print(u,v)
    d2 = g2.edges[u,v]
    if not(d2['w1a']==d1['w1a']):
        print(u,v,d2['w1a']==d1['w1a'],d1['w1a'])
print('---done---')
# Out:
# ---done---

# %%
heta2.output_random
# Out:
# False
